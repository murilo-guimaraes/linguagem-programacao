# %% [markdown]
# <a href="https://colab.research.google.com/github/murilo-guimaraes/linguagem-programacao/blob/main/POO%2C_Classes_e_Atributos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# #**PROGRAMAÇÃO ORIENTADA A OBJETOS: CLASSES E ATRIBUTOS**
#
# ####**Relatório Técnico Acadêmico | L. Programação 2026 | Colaboratory**
# **Data: 13/04/2026**
# <div>POO | Classes | Objetos | Atributos | Instanciação</div>
#
# *Baseado na Unidade 3 Seção 1 do livro **Linguagem de Programação** (Vanessa Cadan Scheffer)*

# %% [markdown]
# ##**Introdução Teórica**
#
# A Programação Orientada a Objetos (POO) surgiu como uma solução para a crescente complexidade dos softwares procedurais. Segundo Scheffer (2020), o paradigma orientado a objetos permite que o desenvolvedor mapeie elementos do mundo real para o código através de **Classes**. Uma classe funciona como um molde ou "planta baixa", definindo quais características (**Atributos**) e comportamentos (**Métodos**) um objeto possuirá. No Python, a utilização da palavra-chave `class` e do método especial `__init__` são os pilares para a criação de sistemas modulares, onde cada objeto é uma instância viva dessa definição abstrata.

# %% [markdown]
# ---
# ##**Objetivos**
#
#  - **Definir** a estrutura de uma classe utilizando a sintaxe oficial do Python.
#  - **Implementar** o método construtor `__init__` para inicialização de estado.
#  - **Demonstrar** o processo de instanciação de múltiplos objetos a partir de uma mesma classe.
#  - **Validar** a manipulação de atributos e a independência de estado entre instâncias.

# %% [markdown]
# ---
# ###**1. Definição da Classe e Construtor**
#
# Uma classe define o tipo do objeto. O método `__init__` é o responsável por atribuir os valores iniciais (estado) no momento em que o objeto nasce.

# %%
class Veiculo:
    def __init__(self, marca, modelo, ano):
        # Atributos de Instância
        self.marca = marca
        self.modelo = modelo
        self.ano = ano
        self.ligado = False

# Criando um objeto (Instanciação)
meu_carro = Veiculo("Toyota", "Corolla", 2024)

print(f"Objeto criado: {meu_carro.marca} {meu_carro.modelo} ({meu_carro.ano})")
# Out:
# Objeto criado: Toyota Corolla (2024)

# %% [markdown]
# ####**O que observar:**
# <a>O parâmetro `self` é fundamental: ele garante que os atributos pertençam especificamente àquela instância. Como explicado por Scheffer, a classe `Veiculo` é apenas o conceito; `meu_carro` é o objeto real ocupando espaço na memória.</a>

# %% [markdown]
# ---
# ###**2. Métodos: O Que o Objeto Faz**
#
# Métodos são funções definidas dentro da classe que representam as ações que o objeto pode realizar.

# %%
class Veiculo:
    def __init__(self, marca, modelo):
        self.marca = marca
        self.modelo = modelo
        self.ligado = False

    def ligar(self):
        self.ligado = True
        print(f"O {self.modelo} está ligado agora.")

    def exibir_status(self):
        status = "Ligado" if self.ligado else "Desligado"
        print(f"Status do {self.modelo}: {status}")

# Testando comportamentos
carro_viva = Veiculo("Honda", "Civic")
carro_viva.exibir_status()
carro_viva.ligar()
carro_viva.exibir_status()
# Out:
# Status do Civic: Desligado
# O Civic está ligado agora.
# Status do Civic: Ligado

# %% [markdown]
# ####**O que observar:**
# <a>Os métodos alteram o "estado" interno do objeto. Note que ao chamar `.ligar()`, alteramos o atributo `self.ligado`. Isso demonstra o princípio de que o objeto é responsável por gerenciar seus próprios dados.</a>

# %% [markdown]
# ---
# ### **3. Instanciação Múltipla e Visualização de Dados**
#
# Nesta etapa, validamos a capacidade de criar múltiplos objetos a partir de uma mesma classe, conforme a Unidade 3 de Vanessa Scheffer. Simularemos um sistema de inventário onde cada instância da classe `Produto` armazena dados específicos. Para tornar a análise profissional, utilizaremos um gráfico de barras que consolida os atributos de cada objeto, demonstrando como a POO facilita a organização de grandes volumes de dados estruturados.

# %%
import matplotlib.pyplot as plt

class Produto:
    def __init__(self, nome, quantidade):
        self.nome = nome
        self.quantidade = quantidade

# Criando instâncias (Objetos)
produtos = [
    Produto("Processador", 15),
    Produto("Memória RAM", 42),
    Produto("SSD 512GB", 28),
    Produto("Placa Mãe", 10)
]

# Extraindo dados dos objetos para o gráfico
nomes = [p.nome for p in produtos]
estoque = [p.quantidade for p in produtos]

plt.figure(figsize=(9, 4))
plt.bar(nomes, estoque, color='#8e44ad', edgecolor='#713391')

# Adicionando rótulos sobre as barras
for i, v in enumerate(estoque):
    plt.text(i, v + 1, str(v), ha='center', fontweight='bold')

plt.title('Controle de Estoque via Instanciação de Objetos')
plt.ylabel('Quantidade em Unidades')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# %% [markdown]
# #### **O que observar:**
# <a>O gráfico de barras representa visualmente o estado atual de cada instância da classe `Produto`. Note que, embora todos os objetos derivem do mesmo "molde" (Classe), cada um mantém seus próprios valores de atributos de forma independente. Como destaca Scheffer, essa independência entre instâncias é o que permite gerenciar sistemas complexos, como um estoque de TI, de maneira modular, onde a alteração no atributo de um objeto não afeta a integridade dos demais.</a>

# %% [markdown]
# ---
# ##**Conclusão**
#
# A exploração prática da Unidade 3 Seção 1 confirmou que a transição para a Programação Orientada a Objetos exige uma mudança de mentalidade: do "como fazer" (procedural) para o "quem faz" (objeto). A estrutura de Classes e Atributos apresentada por Vanessa Scheffer fornece a base necessária para a construção de códigos reutilizáveis e organizados. Ao dominar a criação de moldes eficientes e a manipulação de instâncias, o desenvolvedor ganha a habilidade de projetar sistemas que refletem a lógica do negócio, facilitando a manutenção e a expansão futura do software.

# %% [markdown]
# ---
# ##**Referências Bibliográficas**
#
# SCHEFFER, Vanessa Cadan. **Linguagem de programação**: Introdução à POO. Londrina: Editora e Distribuidora Educacional S.A., 2020.
#
# WEISFELD, Matt. **The Object-Oriented Thought Process**. 4. ed. [S. l.]: Addison-Wesley Professional, 2013.
#
# PORTAL INTERATIVA. **Linguagem de Programação: Livro Digital**. Disponível em: AVA Educacional. Acesso em: 13 abr. 2026.

# %% [markdown]
# ---
# <p align="center"><b>© 2026 Murilo Guimarães. Acadêmico de ADS.</b></p>
#
# ---
